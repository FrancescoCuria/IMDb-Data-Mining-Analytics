# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
OUT_PATH = 'output'

# %%
# Data sample
df = pd.read_csv('data/train.csv', skipinitialspace=True)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16431 entries, 0 to 16430
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   originalTitle                16431 non-null  object
#  1   rating                       16431 non-null  object
#  2   startYear                    16431 non-null  int64
#  3   endYear                      16431 non-null  object
#  4   runtimeMinutes               16431 non-null  object
#  5   awardWins                    13813 non-null  float64
#  6   numVotes                     16431 non-null  int64
#  7   worstRating                  16431 non-null  int64
#  8   bestRating                   16431 non-null  int64
#  9   totalImages                  16431 non-null  int64
#  10  totalVideos                  16431 non-null  int64
#  11  totalCredits                 16431 non-null  int64
#  12  criticReviewsTotal           16431 non-null  int64
#  13  titleType                    16431 non-null  object
#  14  awardNominationsExcludeWins  16431 non-null  int64
#  15  canHaveEpisodes              16431 non-null  bool
#  16  isRatable                    16431 non-null  bool
#  17  isAdult                      16431 non-null  int64
#  18  numRegions                   16431 non-null  int64
#  19  userReviewsTotal             16431 non-null  int64
#  20  ratingCount                  16431 non-null  int64
#  21  countryOfOrigin              16431 non-null  object
#  22  genres                       16431 non-null  object
# dtypes: bool(2), float64(1), int64(13), object(7)
# memory usage: 2.7+ MB
#                              originalTitle  rating  startYear endYear  \
# 0  Neogenic Nightmare Chapter 3: Hydro-Man  (7, 8]       1995      \N
# 1                                  Looping  (5, 6]       1982      \N
# 2                           Idealnaya para  (5, 6]       1992      \N
# 3              MasterChef Celebrity México  (5, 6]       2021      \N
# 4                              Seutateueob  (7, 8]       2020    2020
#
#   runtimeMinutes  awardWins  numVotes  worstRating  bestRating  totalImages  \
# 0             \N        0.0       779            1          10            1
# 1             \N        0.0        11            1          10            1
# 2             \N        0.0        38            1          10            1
# 3             \N        0.0        15            1          10           22
# 4             80        1.0     15718            1          10          347
#
#    ...  titleType  awardNominationsExcludeWins  canHaveEpisodes isRatable  \
# 0  ...  tvEpisode                            0            False      True
# 1  ...  videoGame                            0            False      True
# 2  ...      movie                            0            False      True
# 3  ...   tvSeries                            0             True      True
# 4  ...   tvSeries                            1             True      True
#
#    isAdult  numRegions  userReviewsTotal  ratingCount  countryOfOrigin  \
# 0        0           1                 0          781           ['US']
# 1        0           1                 0           11          ['XWG']
# 2        0           1                 1           38           ['RU']
# 3        0           1                 0           15           ['MX']
# 4        0          32               452        15746           ['KR']
#
#                        genres
# 0  Action,Adventure,Animation
# 1                      Action
# 2                      Comedy
# 3                  Reality-TV
# 4        Comedy,Drama,Romance
#
# [5 rows x 23 columns]

# %% [markdown]
# ## DATA UNDERSTANDING AND PREPARATION

# %% [markdown]
# ### 1) Data Semantics
# - originalTitle:
# Original title, in the original language.
# Nominal
# Non-Null
# - runtimeMinutes:
# Primary runtime of the title, in minutes.
# Ratio
# Non-Null
# - isAdult:
# Whether or not the title is for adult. 0: non-adult title; 1: adult title.
# Binary
# - startYear:
# Represents the release year of a title. In the case of TV Series, it is the series start year.
# Ordinal
# - endYear:
# TV Series end year.
# Numeric
# - numVotes:
# Number of votes the title has received.
# Numeric
# - numRegions:
# The regions number for this version of the title.
# Nominal
# - worstRating:
# Worst title rating.
# Ordinal
# - bestRating:
# Best title rating.
# Ordinal
# - canHaveEpisodes:
# Whether or not the title can have episodes.
# Binary
# - isRatable:
# Whether or not the title can be rated by users.
# Binary
# - totalImages:
# Total Number of Images for the title within the IMDb title page.
# Numeric
# - totalVideos:
# Total Number of Videos for the title within the IMDb title page.
# Numeric
# - totalCredits:
# Total Number of Credits for the title.
# Numeric
# - criticReviewsTotal:
# Total Number of Critic Reviews.
# Numeric
# - awardWins:
# Number of awards the title won.
# Numeric
# - awardNominationsExcludeWins:
# Number of award nominations excluding wins.
# Numeric
# - titleType:
# The type/format of the title (e.g. movie, short, tvseries, tvepisode, video, etc).
# Categorical
# - rating:
# IMDB title rating class.
# Numeric
# - ratingCount:
# The total number of user ratings submitted for the title.
# Ratio
# - countryOfOrigin:
# The country where the title was primarily produced.
# Categorical
# - genres:
# The genre(s) associated with the title (e.g., drama, comedy, action).
# Categorical
# - userReviewsTotal:
# Total Number of Users Reviews.
# Ratio

# %% [markdown]
# ### 2) Assessing Data Quality

# %%
# Cast columns to right type.
df['endYear'] = pd.to_numeric(df['endYear'], errors='coerce', downcast='integer')
df['runtimeMinutes'] = pd.to_numeric(df['runtimeMinutes'], errors='coerce', downcast='integer')
df['isAdult'] = [val != 0 for val in df['isAdult']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16431 entries, 0 to 16430
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   originalTitle                16431 non-null  object
#  1   rating                       16431 non-null  object
#  2   startYear                    16431 non-null  int64
#  3   endYear                      814 non-null    float64
#  4   runtimeMinutes               11579 non-null  float64
#  5   awardWins                    13813 non-null  float64
#  6   numVotes                     16431 non-null  int64
#  7   worstRating                  16431 non-null  int64
#  8   bestRating                   16431 non-null  int64
#  9   totalImages                  16431 non-null  int64
#  10  totalVideos                  16431 non-null  int64
#  11  totalCredits                 16431 non-null  int64
#  12  criticReviewsTotal           16431 non-null  int64
#  13  titleType                    16431 non-null  object
#  14  awardNominationsExcludeWins  16431 non-null  int64
#  15  canHaveEpisodes              16431 non-null  bool
#  16  isRatable                    16431 non-null  bool
#  17  isAdult                      16431 non-null  bool
#  18  numRegions                   16431 non-null  int64
#  19  userReviewsTotal             16431 non-null  int64
#  20  ratingCount                  16431 non-null  int64
#  21  countryOfOrigin              16431 non-null  object
#  22  genres                       16431 non-null  object
# dtypes: bool(3), float64(3), int64(12), object(5)
# memory usage: 2.6+ MB

# %%
# Clean ratings (from "(x, y]" to y : int)
df['rating'] = df['rating'].apply( lambda rt : int(rt.split(',')[1].replace(']', '')) )
df.head()
# Out:
#                              originalTitle  rating  startYear  endYear  \
# 0  Neogenic Nightmare Chapter 3: Hydro-Man       8       1995      NaN
# 1                                  Looping       6       1982      NaN
# 2                           Idealnaya para       6       1992      NaN
# 3              MasterChef Celebrity México       6       2021      NaN
# 4                              Seutateueob       8       2020   2020.0
#
#    runtimeMinutes  awardWins  numVotes  worstRating  bestRating  totalImages  \
# 0             NaN        0.0       779            1          10            1
# 1             NaN        0.0        11            1          10            1
# 2             NaN        0.0        38            1          10            1
# 3             NaN        0.0        15            1          10           22
# 4            80.0        1.0     15718            1          10          347
#
#    ...  titleType  awardNominationsExcludeWins  canHaveEpisodes isRatable  \
# 0  ...  tvEpisode                            0            False      True
# 1  ...  videoGame                            0            False      True
# 2  ...      movie                            0            False      True
# 3  ...   tvSeries                            0             True      True
# 4  ...   tvSeries                            1             True      True
#
#    isAdult  numRegions  userReviewsTotal  ratingCount  countryOfOrigin  \
# 0    False           1                 0          781           ['US']
# 1    False           1                 0           11          ['XWG']
# 2    False           1                 1           38           ['RU']
# 3    False           1                 0           15           ['MX']
# 4    False          32               452        15746           ['KR']
#
#                        genres
# 0  Action,Adventure,Animation
# 1                      Action
# 2                      Comedy
# 3                  Reality-TV
# 4        Comedy,Drama,Romance
#
# [5 rows x 23 columns]

# %%
# Check that bestRating and worstRating are constant columns.
print('entries in bestRating != 10:', len(df[df['bestRating'] != 10]))
print('entries in worstRating != 1:', len(df[df['worstRating'] != 1]))
# Out:
# entries in bestRating != 10: 0
# entries in worstRating != 1: 0

# %%
# Removing columns bestRating and worstRating
df.drop(['bestRating', 'worstRating'], axis=1, inplace=True)
df.head()
# Out:
#                              originalTitle  rating  startYear  endYear  \
# 0  Neogenic Nightmare Chapter 3: Hydro-Man       8       1995      NaN
# 1                                  Looping       6       1982      NaN
# 2                           Idealnaya para       6       1992      NaN
# 3              MasterChef Celebrity México       6       2021      NaN
# 4                              Seutateueob       8       2020   2020.0
#
#    runtimeMinutes  awardWins  numVotes  totalImages  totalVideos  \
# 0             NaN        0.0       779            1            0
# 1             NaN        0.0        11            1            0
# 2             NaN        0.0        38            1            0
# 3             NaN        0.0        15           22            0
# 4            80.0        1.0     15718          347            2
#
#    totalCredits  ...  titleType awardNominationsExcludeWins  canHaveEpisodes  \
# 0            21  ...  tvEpisode                           0            False
# 1             1  ...  videoGame                           0            False
# 2            24  ...      movie                           0            False
# 3            56  ...   tvSeries                           0             True
# 4            47  ...   tvSeries                           1             True
#
#    isRatable  isAdult  numRegions  userReviewsTotal  ratingCount  \
# 0       True    False           1                 0          781
# 1       True    False           1                 0           11
# 2       True    False           1                 1           38
# 3       True    False           1                 0           15
# 4       True    False          32               452        15746
#
#    countryOfOrigin                      genres
# 0           ['US']  Action,Adventure,Animation
# 1          ['XWG']                      Action
# 2           ['RU']                      Comedy
# 3           ['MX']                  Reality-TV
# 4           ['KR']        Comedy,Drama,Romance
#
# [5 rows x 21 columns]

# %%
# Check how many rows contains '\N' in object type columns and replace them with None.
print( 'Object-type columns containing \"\\N\":', len(df[df.map(lambda x: x == '\\N').any(axis=1)]))
df.replace('\\N', None, inplace=True)
print(len(df[df.map(lambda x: x == '\\N').any(axis=1)]))
df.info()
# Out:
# Object-type columns containing "\N": 382
# 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16431 entries, 0 to 16430
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   originalTitle                16431 non-null  object
#  1   rating                       16431 non-null  int64
#  2   startYear                    16431 non-null  int64
#  3   endYear                      814 non-null    float64
#  4   runtimeMinutes               11579 non-null  float64
#  5   awardWins                    13813 non-null  float64
#  6   numVotes                     16431 non-null  int64
#  7   totalImages                  16431 non-null  int64
#  8   totalVideos                  16431 non-null  int64
#  9   totalCredits                 16431 non-null  int64
#  10  criticReviewsTotal           16431 non-null  int64
#  11  titleType                    16431 non-null  object
#  12  awardNominationsExcludeWins  16431 non-null  int64
#  13  canHaveEpisodes              16431 non-null  bool
#  14  isRatable                    16431 non-null  bool
#  15  isAdult                      16431 non-null  bool
#  16  numRegions                   16431 non-null  int64
#  17  userReviewsTotal             16431 non-null  int64
#  18  ratingCount                  16431 non-null  int64
#  19  countryOfOrigin              16431 non-null  object
#  20  genres                       16049 non-null  object
# dtypes: bool(3), float64(3), int64(11), object(4)
# memory usage: 2.3+ MB

# %%
# Reformat 'genre' column. Check max number of genres in the column, and make the same number as columns called [genre1, genre2, ...] with cardinal values.
print("Max number of genres in \"genres\" column: ", df['genres'].apply(lambda x: len(x.split(',')) if isinstance(x, str) else 0).max())
df[['genre1', 'genre2', 'genre3']] = df['genres'].str.split(',', expand=True)
df['genre1'] = df['genre1'].apply(lambda s : s.strip().title() if s else None)
df['genre2'] = df['genre2'].apply(lambda s : s.strip().title() if s else None)
df['genre3'] = df['genre3'].apply(lambda s : s.strip().title() if s else None)
df.drop('genres', axis=1, inplace=True)
# Out:
# Max number of genres in "genres" column:  3

# %%
# Find Duplicates (rows in general)
duplicated_rows = df[df.duplicated(keep=False)].reset_index(drop=True)
print(len(duplicated_rows))
del duplicated_rows
# Out:
# 0

# %%
# Find Duplicates (on title)
duplicated_titles = df[df.duplicated(subset='originalTitle', keep=False)]['originalTitle']
duplicated_titles = df[ df['originalTitle'].isin(duplicated_titles) ].sort_values('originalTitle')
print("Duplicated titles (%) :", len(duplicated_titles) / len(df) * 100  )
duplicated_titles
# Out:
# Duplicated titles (%) : 3.4873105714807373
#              originalTitle  rating  startYear  endYear  runtimeMinutes  \
# 6658             Abandoned       3       2017      NaN               4
# 6065             Abandoned       9       1994      NaN              47
# 1493               Aladdin       8       1993      NaN              28
# 15178              Aladdin       7       1994      NaN              28
# 2471                 Alone       7       2007      NaN              12
# ...                    ...     ...        ...      ...             ...
# 12439  Where Are They Now?       8       2017      NaN              40
# 12059                 Zero       5       2010      NaN              15
# 6060                  Zero       9       2018      NaN              52
# 11955            Épisode 1       6       2023      NaN              33
# 14523            Épisode 1       7       2017      NaN              47
#
#        awardWins  totalImages  totalVideos  totalCredits  criticReviewsTotal  \
# 6658         0.0            1            0             6                   0
# 6065         0.0            3            0            86                   0
# 1493         0.0            9            0           169                   1
# 15178        0.0            2            0             3                   0
# 2471         0.0            1            0            14                   0
# ...          ...          ...          ...           ...                 ...
# 12439        0.0            1            0            29                   0
# 12059        0.0            2            0            17                   0
# 6060         0.0            0            0           123                   0
# 11955        NaN            4            0            63                   0
# 14523        NaN            0            0            61                   0
#
#        ... isAdult  numRegions  userReviewsTotal  countryOfOrigin  genre1  \
# 6658   ...   False           1                 0           ['RU']  Horror
# 6065   ...   False           1                 0           ['AU']  Action
# 1493   ...   False           3                 3           ['US']  Action
# 15178  ...   False           2                 0           ['JP']  Action
# 2471   ...   False           1                 0           ['US']   Short
# ...    ...     ...         ...               ...              ...     ...
# 12439  ...   False           1                 0           ['US']   Crime
# 12059  ...   False           1                 0           ['NZ']   Drama
# 6060   ...   False           1                 2           ['ES']   Drama
# 11955  ...   False           1                 0     ['FR', 'US']  Comedy
# 14523  ...   False           1                 0           ['FR']   Crime
#
#             genre2      genre3 totVotes titleTypeNumeric clustering
# 6658         Short        None       26                1          0
# 6065         Crime       Drama       30                2          3
# 1493     Adventure      Family     1047                9          7
# 15178    Adventure      Family       18                9          6
# 2471      Thriller        None       10                1          6
# ...            ...         ...      ...              ...        ...
# 12439  Documentary  Reality-Tv       37                2          7
# 12059        Short        None        8                1          0
# 6060       Fantasy     Romance       92                2          3
# 11955        Drama        None       15                2          0
# 14523        Drama    Thriller       15                2          6
#
# [573 rows x 24 columns]

# %%
# DB Check Correlation Between Groups of Entries with the same Title
same_title_correl = {} 
for title, group in duplicated_titles.groupby('originalTitle'):
    # Compute the correlation matrix for each group
    same_title_correl[title] = group.corr(numeric_only=True)

# Display the correlation matrices for each title group
for title, corr_matrix in same_title_correl.items():
    print(f"\nCorrelation matrix for title '{title}':\n{corr_matrix}")
# Out:
# Correlation matrix for title 'Abandoned':
#                              rating  startYear  endYear  runtimeMinutes  \
# rating                          1.0       -1.0      NaN             1.0
# startYear                      -1.0        1.0      NaN            -1.0
# endYear                         NaN        NaN      NaN             NaN
# runtimeMinutes                  1.0       -1.0      NaN             1.0
# awardWins                       NaN        NaN      NaN             NaN
# numVotes                        1.0       -1.0      NaN             1.0
# totalImages                     1.0       -1.0      NaN             1.0
# totalVideos                     NaN        NaN      NaN             NaN
# totalCredits                    1.0       -1.0      NaN             1.0
# criticReviewsTotal              NaN        NaN      NaN             NaN
# awardNominationsExcludeWins     NaN        NaN      NaN             NaN
# canHaveEpisodes                 NaN        NaN      NaN             NaN
# isRatable                       NaN        NaN      NaN             NaN
# isAdult                         NaN        NaN      NaN             NaN
# numRegions                      NaN        NaN      NaN             NaN
# userReviewsTotal                NaN        NaN      NaN             NaN
# ratingCount                     1.0       -1.0      NaN             1.0
#
#                              awardWins  numVotes  totalImages  totalVideos  \
# rating                             NaN       1.0          1.0          NaN
# startYear                          NaN      -1.0         -1.0          NaN
# endYear                            NaN       NaN          NaN          NaN
# runtimeMinutes                     NaN       1.0          1.0          NaN
# awardWins                          NaN       NaN          NaN          NaN
# numVotes                           NaN       1.0          1.0          NaN
# totalImages                        NaN       1.0          1.0          NaN
# totalVideos                        NaN       NaN          NaN          NaN
# totalCredits                       NaN       1.0          1.0          NaN
# criticReviewsTotal                 NaN       NaN          NaN          NaN
# awardNominationsExcludeWins        NaN       NaN          NaN          NaN
# canHaveEpisodes                    NaN       NaN          NaN          NaN
# isRatable                          NaN       NaN          NaN          NaN
# isAdult                            NaN       NaN          NaN          NaN
# numRegions                         NaN       NaN          NaN          NaN
# userReviewsTotal                   NaN       NaN          NaN          NaN
# ratingCount                        NaN       1.0          1.0          NaN
#
#                              totalCredits  criticReviewsTotal  \
# rating                                1.0                 NaN
# startYear                            -1.0                 NaN
# endYear                               NaN                 NaN
# runtimeMinutes                        1.0                 NaN
# awardWins                             NaN                 NaN
# numVotes                              1.0                 NaN
# totalImages                           1.0                 NaN
# totalVideos                           NaN                 NaN
# totalCredits                          1.0                 NaN
# criticReviewsTotal                    NaN                 NaN
# awardNominationsExcludeWins           NaN                 NaN
# canHaveEpisodes                       NaN                 NaN
# isRatable                             NaN                 NaN
# isAdult                               NaN                 NaN
# numRegions                            NaN                 NaN
# userReviewsTotal                      NaN                 NaN
# ratingCount                           1.0                 NaN
#
#                              awardNominationsExcludeWins  canHaveEpisodes  \
# rating                                               NaN              NaN
# startYear                                            NaN              NaN
# endYear                                              NaN              NaN
# runtimeMinutes                                       NaN              NaN
# awardWins                                            NaN              NaN
# numVotes                                             NaN              NaN
# totalImages                                          NaN              NaN
# totalVideos                                          NaN              NaN
# totalCredits                                         NaN              NaN
# criticReviewsTotal                                   NaN              NaN
# awardNominationsExcludeWins                          NaN              NaN
# canHaveEpisodes                                      NaN              NaN
# isRatable                                            NaN              NaN
# isAdult                                              NaN              NaN
# numRegions                                           NaN              NaN
# userReviewsTotal                                     NaN              NaN
# ratingCount                                          NaN              NaN
#
#                              isRatable  isAdult  numRegions  userReviewsTotal  \
# rating                             NaN      NaN         NaN               NaN
# startYear                          NaN      NaN         NaN               NaN
# endYear                            NaN      NaN         NaN               NaN
# runtimeMinutes                     NaN      NaN         NaN               NaN
# awardWins                          NaN      NaN         NaN               NaN
# numVotes                           NaN      NaN         NaN               NaN
# totalImages                        NaN      NaN         NaN               NaN
# totalVideos                        NaN      NaN         NaN               NaN
# totalCredits                       NaN      NaN         NaN               NaN
# criticReviewsTotal                 NaN      NaN         NaN               NaN
# awardNominationsExcludeWins        NaN      NaN         NaN               NaN
# canHaveEpisodes                    NaN      NaN         NaN               NaN
# isRatable                          NaN      NaN         NaN               NaN
# isAdult                            NaN      NaN         NaN               NaN
# numRegions                         NaN      NaN         NaN               NaN
# userReviewsTotal                   NaN      NaN         NaN               NaN
# ratingCount                        NaN      NaN         NaN               NaN
#
#                              ratingCount
# rating                               1.0
# startYear                           -1.0
# endYear                              NaN
# runtimeMinutes                       1.0
# awardWins                            NaN
# numVotes                             1.0
# totalImages                          1.0
# totalVideos                          NaN
# totalCredits                         1.0
# criticReviewsTotal                   NaN
# awardNominationsExcludeWins          NaN
# canHaveEpisodes                      NaN
# isRatable                            NaN
# isAdult                              NaN
# numRegions                           NaN
# userReviewsTotal                     NaN
# ratingCount                          1.0
#
# Correlation matrix for title 'Aladdin':
#                              rating  startYear  endYear  runtimeMinutes  \
# rating                          1.0       -1.0      NaN             NaN
# startYear                      -1.0        1.0      NaN             NaN
# endYear                         NaN        NaN      NaN             NaN
# runtimeMinutes                  NaN        NaN      NaN             NaN
# awardWins                       NaN        NaN      NaN             NaN
# numVotes                        1.0       -1.0      NaN             NaN
# totalImages                     1.0       -1.0      NaN             NaN
# totalVideos                     NaN        NaN      NaN             NaN
# totalCredits                    1.0       -1.0      NaN             NaN
# criticReviewsTotal              1.0       -1.0      NaN             NaN
# awardNominationsExcludeWins     1.0       -1.0      NaN             NaN
# canHaveEpisodes                 NaN        NaN      NaN             NaN
# isRatable                       NaN        NaN      NaN             NaN
# isAdult                         NaN        NaN      NaN             NaN
# numRegions                      1.0       -1.0      NaN             NaN
# userReviewsTotal                1.0       -1.0      NaN             NaN
# ratingCount                     1.0       -1.0      NaN             NaN
#
#                              awardWins  numVotes  totalImages  totalVideos  \
# rating                             NaN       1.0          1.0          NaN
# startYear                          NaN      -1.0         -1.0          NaN
# endYear                            NaN       NaN          NaN          NaN
# runtimeMinutes                     NaN       NaN          NaN          NaN
# awardWins                          NaN       NaN          NaN          NaN
# numVotes                           NaN       1.0          1.0          NaN
# totalImages                        NaN       1.0          1.0          NaN
# totalVideos                        NaN       NaN          NaN          NaN
# totalCredits                       NaN       1.0          1.0          NaN
# criticReviewsTotal                 NaN       1.0          1.0          NaN
# awardNominationsExcludeWins        NaN       1.0          1.0          NaN
# canHaveEpisodes                    NaN       NaN          NaN          NaN
# isRatable                          NaN       NaN          NaN          NaN
# isAdult                            NaN       NaN          NaN          NaN
# numRegions                         NaN       1.0          1.0          NaN
# userReviewsTotal                   NaN       1.0          1.0          NaN
# ratingCount                        NaN       1.0          1.0          NaN
#
#                              totalCredits  criticReviewsTotal  \
# rating                                1.0                 1.0
# startYear                            -1.0                -1.0
# endYear                               NaN                 NaN
# runtimeMinutes                        NaN                 NaN
# awardWins                             NaN                 NaN
# numVotes                              1.0                 1.0
# totalImages                           1.0                 1.0
# totalVideos                           NaN                 NaN
# totalCredits                          1.0                 1.0
# criticReviewsTotal                    1.0                 1.0
# awardNominationsExcludeWins           1.0                 1.0
# canHaveEpisodes                       NaN                 NaN
# isRatable                             NaN                 NaN
# isAdult                               NaN                 NaN
# numRegions                            1.0                 1.0
# userReviewsTotal                      1.0                 1.0
# ratingCount                           1.0                 1.0
#
#                              awardNominationsExcludeWins  canHaveEpisodes  \
# rating                                               1.0              NaN
# startYear                                           -1.0              NaN
# endYear                                              NaN              NaN
# runtimeMinutes                                       NaN              NaN
# awardWins                                            NaN              NaN
# numVotes                                             1.0              NaN
# totalImages                                          1.0              NaN
# totalVideos                                          NaN              NaN
# totalCredits                                         1.0              NaN
# criticReviewsTotal                                   1.0              NaN
# awardNominationsExcludeWins                          1.0              NaN
# canHaveEpisodes                                      NaN              NaN
# isRatable                                            NaN              NaN
# isAdult                                              NaN              NaN
# numRegions                                           1.0              NaN
# userReviewsTotal                                     1.0              NaN
# ratingCount                                          1.0              NaN
#
#                              isRatable  isAdult  numRegions  userReviewsTotal  \
# rating                             NaN      NaN         1.0               1.0
# startYear                          NaN      NaN        -1.0              -1.0
# endYear                            NaN      NaN         NaN               NaN
# runtimeMinutes                     NaN      NaN         NaN               NaN
# awardWins                          NaN      NaN         NaN               NaN
# numVotes                           NaN      NaN         1.0               1.0
# totalImages                        NaN      NaN         1.0               1.0
# totalVideos                        NaN      NaN         NaN               NaN
# totalCredits                       NaN      NaN         1.0               1.0
# criticReviewsTotal                 NaN      NaN         1.0               1.0
# awardNominationsExcludeWins        NaN      NaN         1.0               1.0
# canHaveEpisodes                    NaN      NaN         NaN               NaN
# isRatable                          NaN      NaN         NaN               NaN
# isAdult                            NaN      NaN         NaN               NaN
# numRegions                         NaN      NaN         1.0               1.0
# userReviewsTotal                   NaN      NaN         1.0               1.0
# ratingCount                        NaN      NaN         1.0               1.0
#
#                              ratingCount
# rating                               1.0
# startYear                           -1.0
# endYear                              NaN
# runtimeMinutes                       NaN
# awardWins                            NaN
# numVotes                             1.0
# totalImages                          1.0
# totalVideos                          NaN
# totalCredits                         1.0
# criticReviewsTotal                   1.0
# awardNominationsExcludeWins          1.0
# canHaveEpisodes                      NaN
# isRatable                            NaN
# isAdult                              NaN
# numRegions                           1.0
# userReviewsTotal                     1.0
# ratingCount                          1.0
#
# Correlation matrix for title 'Alone':
#                                rating  startYear  endYear  runtimeMinutes  \
# rating                       1.000000  -0.693375      NaN             1.0
# startYear                   -0.693375   1.000000      NaN            -1.0
# endYear                           NaN        NaN      NaN             NaN
# runtimeMinutes               1.000000  -1.000000      NaN             1.0
# awardWins                         NaN        NaN      NaN             NaN
# numVotes                     0.000000   0.720577      NaN             NaN
# totalImages                  0.000000  -0.720577      NaN             NaN
# totalVideos                       NaN        NaN      NaN             NaN
# totalCredits                 0.944911  -0.419314      NaN             1.0
# criticReviewsTotal                NaN        NaN      NaN             NaN
# awardNominationsExcludeWins       NaN        NaN      NaN             NaN
# canHaveEpisodes                   NaN        NaN      NaN             NaN
# isRatable                         NaN        NaN      NaN             NaN
# isAdult                           NaN        NaN      NaN             NaN
# numRegions                        NaN        NaN      NaN             NaN
# userReviewsTotal                  NaN        NaN      NaN             NaN
# ratingCount                  0.000000   0.720577      NaN             NaN
#
#                              awardWins  numVotes  totalImages  totalVideos  \
# rating                             NaN  0.000000     0.000000          NaN
# startYear                          NaN  0.720577    -0.720577          NaN
# endYear                            NaN       NaN          NaN          NaN
# runtimeMinutes                     NaN       NaN          NaN          NaN
# awardWins                          NaN       NaN          NaN          NaN
# numVotes                           NaN  1.000000    -1.000000          NaN
# totalImages                        NaN -1.000000     1.000000          NaN
# totalVideos                        NaN       NaN          NaN          NaN
# totalCredits                       NaN  0.327327    -0.327327          NaN
# criticReviewsTotal                 NaN       NaN          NaN          NaN
# awardNominationsExcludeWins        NaN       NaN          NaN          NaN
# canHaveEpisodes                    NaN       NaN          NaN          NaN
# isRatable                          NaN       NaN          NaN          NaN
# isAdult                            NaN       NaN          NaN          NaN
# numRegions                         NaN       NaN          NaN          NaN
# userReviewsTotal                   NaN       NaN          NaN          NaN
# ratingCount                        NaN  1.000000    -1.000000          NaN
#
#                              totalCredits  criticReviewsTotal  \
# rating                           0.944911                 NaN
# startYear                       -0.419314                 NaN
# endYear                               NaN                 NaN
# runtimeMinutes                   1.000000                 NaN
# awardWins                             NaN                 NaN
# numVotes                         0.327327                 NaN
# totalImages                     -0.327327                 NaN
# totalVideos                           NaN                 NaN
# totalCredits                     1.000000                 NaN
# criticReviewsTotal                    NaN                 NaN
# awardNominationsExcludeWins           NaN                 NaN
# canHaveEpisodes                       NaN                 NaN
# isRatable                             NaN                 NaN
# isAdult                               NaN                 NaN
# numRegions                            NaN                 NaN
# userReviewsTotal                      NaN                 NaN
# ratingCount                      0.327327                 NaN
#
#                              awardNominationsExcludeWins  canHaveEpisodes  \
# rating                                               NaN              NaN
# startYear                                            NaN              NaN
# endYear                                              NaN              NaN
# runtimeMinutes                                       NaN              NaN
# awardWins                                            NaN              NaN
# numVotes                                             NaN              NaN
# totalImages                                          NaN              NaN
# totalVideos                                          NaN              NaN
# totalCredits                                         NaN              NaN
# criticReviewsTotal                                   NaN              NaN
# awardNominationsExcludeWins                          NaN              NaN
# canHaveEpisodes                                      NaN              NaN
# isRatable                                            NaN              NaN
# isAdult                                              NaN              NaN
# numRegions                                           NaN              NaN
# userReviewsTotal                                     NaN              NaN
# ratingCount                                          NaN              NaN
#
#                              isRatable  isAdult  numRegions  userReviewsTotal  \
# rating                             NaN      NaN         NaN               NaN
# startYear                          NaN      NaN         NaN               NaN
# endYear                            NaN      NaN         NaN               NaN
# runtimeMinutes                     NaN      NaN         NaN               NaN
# awardWins                          NaN      NaN         NaN               NaN
# numVotes                           NaN      NaN         NaN               NaN
# totalImages                        NaN      NaN         NaN               NaN
# totalVideos                        NaN      NaN         NaN               NaN
# totalCredits                       NaN      NaN         NaN               NaN
# criticReviewsTotal                 NaN      NaN         NaN               NaN
# awardNominationsExcludeWins        NaN      NaN         NaN               NaN
# canHaveEpisodes                    NaN      NaN         NaN               NaN
# isRatable                          NaN      NaN         NaN               NaN
# isAdult                            NaN      NaN         NaN               NaN
# numRegions                         NaN      NaN         NaN               NaN
# userReviewsTotal                   NaN      NaN         NaN               NaN
# ratingCount                        NaN      NaN         NaN               NaN
#
#                              ratingCount
# rating                          0.000000
# startYear                       0.720577
# endYear                              NaN
# runtimeMinutes                       NaN
# awardWins                            NaN
# numVotes                        1.000000
# totalImages                    -1.000000
# totalVideos                          NaN
# totalCredits                    0.327327
# criticReviewsTotal                   NaN
# awardNominationsExcludeWins          NaN
# canHaveEpisodes                      NaN
# isRatable                            NaN
# isAdult                              NaN
# numRegions                           NaN
# userReviewsTotal                     NaN
# ratingCount                     1.000000
#
# Correlation matrix for title 'Amal':
#                              rating  startYear  endYear  runtimeMinutes  \
# rating                          1.0        1.0      NaN            -1.0
# startYear                       1.0        1.0      NaN            -1.0
# endYear                         NaN        NaN      NaN             NaN
# runtimeMinutes                 -1.0       -1.0      NaN             1.0
# awardWins                       1.0        1.0      NaN            -1.0
# numVotes                       -1.0       -1.0      NaN             1.0
# totalImages                     1.0        1.0      NaN            -1.0
# totalVideos                     NaN        NaN      NaN             NaN
# totalCredits                    1.0        1.0      NaN            -1.0
# criticReviewsTotal              NaN        NaN      NaN             NaN
# awardNominationsExcludeWins     1.0        1.0      NaN            -1.0
# canHaveEpisodes                 NaN        NaN      NaN             NaN
# isRatable                       NaN        NaN      NaN             NaN
# isAdult                         NaN        NaN      NaN             NaN
# numRegions                      NaN        NaN      NaN             NaN
# userReviewsTotal                NaN        NaN      NaN             NaN
# ratingCount                    -1.0       -1.0      NaN             1.0
#
#                              awardWins  numVotes  totalImages  totalVideos  \
# rating                             1.0      -1.0          1.0          NaN
# startYear                          1.0      -1.0          1.0          NaN
# endYear                            NaN       NaN          NaN          NaN
# runtimeMinutes                    -1.0       1.0         -1.0          NaN
# awardWins                          1.0      -1.0          1.0          NaN
# numVotes                          -1.0       1.0         -1.0          NaN
# totalImages                        1.0      -1.0          1.0          NaN
# totalVideos                        NaN       NaN          NaN          NaN
# totalCredits                       1.0      -1.0          1.0          NaN
# criticReviewsTotal                 NaN       NaN          NaN          NaN
# awardNominationsExcludeWins        1.0      -1.0          1.0          NaN
# canHaveEpisodes                    NaN       NaN          NaN          NaN
# isRatable                          NaN       NaN          NaN          NaN
# isAdult                            NaN       NaN          NaN          NaN
# numRegions                         NaN       NaN          NaN          NaN
# userReviewsTotal                   NaN       NaN          NaN          NaN
# ratingCount                       -1.0       1.0         -1.0          NaN
#
#                              totalCredits  criticReviewsTotal  \
# rating                                1.0                 NaN
# startYear                             1.0                 NaN
# endYear                               NaN                 NaN
# runtimeMinutes                       -1.0                 NaN
# awardWins                             1.0                 NaN
# numVotes                             -1.0                 NaN
# totalImages                           1.0                 NaN
# totalVideos                           NaN                 NaN
# totalCredits                          1.0                 NaN
# criticReviewsTotal                    NaN                 NaN
# awardNominationsExcludeWins           1.0                 NaN
# canHaveEpisodes                       NaN                 NaN
# isRatable                             NaN                 NaN
# isAdult                               NaN                 NaN
# numRegions                            NaN                 NaN
# userReviewsTotal                      NaN                 NaN
# ratingCount                          -1.0                 NaN
#
#                              awardNominationsExcludeWins  canHaveEpisodes  \
# rating                                               1.0              NaN
# startYear                                            1.0              NaN
# endYear                                              NaN              NaN
# runtimeMinutes                                      -1.0              NaN
# awardWins                                            1.0              NaN
# numVotes                                            -1.0              NaN
# totalImages                                          1.0              NaN
# totalVideos                                          NaN              NaN
# totalCredits                                         1.0              NaN
# criticReviewsTotal                                   NaN              NaN
# awardNominationsExcludeWins                          1.0              NaN
# canHaveEpisodes                                      NaN              NaN
# isRatable                                            NaN              NaN
# isAdult                                              NaN              NaN
# numRegions                                           NaN              NaN
# userReviewsTotal                                     NaN              NaN
# ratingCount                                         -1.0              NaN
#
#                              isRatable  isAdult  numRegions  userReviewsTotal  \
# rating                             NaN      NaN         NaN               NaN
# startYear                          NaN      NaN         NaN               NaN
# endYear                            NaN      NaN         NaN               NaN
# runtimeMinutes                     NaN      NaN         NaN               NaN
# awardWins                          NaN      NaN         NaN               NaN
# numVotes                           NaN      NaN         NaN               NaN
# totalImages                        NaN      NaN         NaN               NaN
# totalVideos                        NaN      NaN         NaN               NaN
# totalCredits                       NaN      NaN         NaN               NaN
# criticReviewsTotal                 NaN      NaN         NaN               NaN
# awardNominationsExcludeWins        NaN      NaN         NaN               NaN
# canHaveEpisodes                    NaN      NaN         NaN               NaN
# isRatable                          NaN      NaN         NaN               NaN
# isAdult                            NaN      NaN         NaN               NaN
# numRegions                         NaN      NaN         NaN               NaN
# userReviewsTotal                   NaN      NaN         NaN               NaN
# ratingCount                        NaN      NaN         NaN               NaN
#
#                              ratingCount
# rating                              -1.0
# startYear                           -1.0
# endYear                              NaN
# runtimeMinutes                       1.0
# awardWins                           -1.0
# numVotes                             1.0
# totalImages                         -1.0
# totalVideos                          NaN
# totalCredits                        -1.0
# criticReviewsTotal                   NaN
# awardNominationsExcludeWins         -1.0
# canHaveEpisodes                      NaN
# isRatable                            NaN
# isAdult                              NaN
# numRegions                           NaN
# userReviewsTotal                     NaN
# ratingCount                          1.0
#
# Correlation matrix for title 'An Eye for an Eye':
#                              rating  startYear  endYear  runtimeMinutes  \
# rating                          1.0        1.0      NaN            -1.0
# startYear                       1.0        1.0      NaN            -1.0
# endYear                         NaN        NaN      NaN             NaN
# runtimeMinutes                 -1.0       -1.0      NaN             1.0
# awardWins                       NaN        NaN      NaN             NaN
# numVotes                        1.0        1.0      NaN            -1.0
# totalImages                     1.0        1.0      NaN            -1.0
# totalVideos                     NaN        NaN      NaN             NaN
# totalCredits                    1.0        1.0      NaN            -1.0
# criticReviewsTotal              NaN        NaN      NaN             NaN
# awardNominationsExcludeWins     NaN        NaN      NaN             NaN
# canHaveEpisodes                 NaN        NaN      NaN             NaN
# isRatable                       NaN        NaN      NaN             NaN
# isAdult                         NaN        NaN      NaN             NaN
# numRegions                      NaN        NaN      NaN             NaN
# userReviewsTotal                NaN        NaN      NaN             NaN
# ratingCount                     1.0        1.0      NaN            -1.0
#
#                              awardWins  numVotes  totalImages  totalVideos  \
# rating                             NaN       1.0          1.0          NaN
# startYear                          NaN       1.0          1.0          NaN
# endYear                            NaN       NaN          NaN          NaN
# runtimeMinutes                     NaN      -1.0         -1.0          NaN
# awardWins                          NaN       NaN          NaN          NaN
# numVotes                           NaN       1.0          1.0          NaN
# totalImages                        NaN       1.0          1.0          NaN
# totalVideos                        NaN       NaN          NaN          NaN
# totalCredits                       NaN       1.0          1.0          NaN
# criticReviewsTotal                 NaN       NaN          NaN          NaN
# awardNominationsExcludeWins        NaN       NaN          NaN          NaN
# canHaveEpisodes                    NaN       NaN          NaN          NaN
# isRatable                          NaN       NaN          NaN          NaN
# isAdult                            NaN       NaN          NaN          NaN
# numRegions                         NaN       NaN          NaN          NaN
# userReviewsTotal                   NaN       NaN          NaN          NaN
# ratingCount                        NaN       1.0          1.0          NaN
#
#                              totalCredits  criticReviewsTotal  \
# rating                                1.0                 NaN
# startYear                             1.0                 NaN
# endYear                               NaN                 NaN
# runtimeMinutes                       -1.0                 NaN
# awardWins                             NaN                 NaN
# numVotes                              1.0                 NaN
# totalImages                           1.0                 NaN
# totalVideos                           NaN                 NaN
# totalCredits                          1.0                 NaN
# criticReviewsTotal                    NaN                 NaN
# awardNominationsExcludeWins           NaN                 NaN
# canHaveEpisodes                       NaN                 NaN
# isRatable                             NaN                 NaN
# isAdult                               NaN                 NaN
# numRegions                            NaN                 NaN
# userReviewsTotal                      NaN                 NaN
# ratingCount                           1.0                 NaN
#
#                              awardNominationsExcludeWins  canHaveEpisodes  \
# rating                                               NaN              NaN
# startYear                                            NaN              NaN
# endYear                                              NaN              NaN
# runtimeMinutes                                       NaN              NaN
# awardWins                                            NaN              NaN
# numVotes                                             NaN              NaN
# totalImages                                          NaN              NaN
# totalVideos                                          NaN              NaN
# totalCredits                                         NaN              NaN
# criticReviewsTotal                                   NaN              NaN
# awardNominationsExcludeWins                          NaN              NaN
# canHaveEpisodes                                      NaN              NaN
# isRatable                                            NaN              NaN
# isAdult                                              NaN              NaN
# numRegions                                           NaN              NaN
# userReviewsTotal                                     NaN              NaN
# ratingCount                                          NaN              NaN
#
#                              isRatable  isAdult  numRegions  userReviewsTotal  \
# rating                             NaN      NaN         NaN               NaN
# startYear                          NaN      NaN         NaN               NaN
# endYear                            NaN      NaN         NaN               NaN
# runtimeMinutes                     NaN      NaN         NaN               NaN
# awardWins                          NaN      NaN         NaN               NaN
# numVotes                           NaN      NaN         NaN               NaN
# totalImages                        NaN      NaN         NaN               NaN
# totalVideos                        NaN      NaN         NaN               NaN
# totalCredits                       NaN      NaN         NaN               NaN
# criticReviewsTotal                 NaN      NaN         NaN               NaN
# awardNominationsExcludeWins        NaN      NaN         NaN               NaN
# canHaveEpisodes                    NaN      NaN         NaN               NaN
# isRatable                          NaN      NaN         NaN               NaN
# isAdult                            NaN      NaN         NaN               NaN
# numRegions                         NaN      NaN         NaN               NaN
# userReviewsTotal                   NaN      NaN         NaN               NaN
# ratingCount                        NaN      NaN         NaN               NaN
#
#                              ratingCount
# rating                               1.0
# startYear                            1.0
# endYear                              NaN
# runtimeMinutes                      -1.0
# awardWins                            NaN
# numVotes                             1.0
# totalImages                          1.0
# totalVideos                          NaN
# totalCredits                         1.0
# criticReviewsTotal                   NaN
# awardNominationsExcludeWins          NaN
# canHaveEpisodes                      NaN
# isRatable                            NaN
# isAdult                              NaN
# numRegions                           NaN
# userReviewsTotal                     NaN
# ratingCount                          1.0
#
# Correlation matrix for title 'Angel':
#                              rating  startYear  endYear  runtimeMinutes  \
# rating                          1.0       -1.0      NaN             NaN
# startYear                      -1.0        1.0      NaN             NaN
# endYear                         NaN        NaN      NaN             NaN
# runtimeMinutes                  NaN        NaN      NaN             NaN
# awardWins                       NaN        NaN      NaN             NaN
# numVotes                        1.0       -1.0      NaN             NaN
# totalImages                     NaN        NaN      NaN             NaN
# totalVideos                     NaN        NaN      NaN             NaN
# totalCredits                    1.0       -1.0      NaN             NaN
# criticReviewsTotal              NaN        NaN      NaN             NaN
# awardNominationsExcludeWins     NaN        NaN      NaN             NaN
# canHaveEpisodes                 NaN        NaN      NaN             NaN
# isRatable                       NaN        NaN      NaN             NaN
# isAdult                         NaN        NaN      NaN             NaN
# numRegions                     -1.0        1.0      NaN             NaN
# userReviewsTotal                1.0       -1.0      NaN             NaN
# ratingCount                     1.0       -1.0      NaN             NaN
#
#                              awardWins  numVotes  totalImages  totalVideos  \
# rating                             NaN       1.0          NaN          NaN
# startYear                          NaN      -1.0          NaN          NaN
# endYear                            NaN       NaN          NaN          NaN
# runtimeMinutes                     NaN       NaN          NaN          NaN
# awardWins                          NaN       NaN          NaN          NaN
# numVotes                           NaN       1.0          NaN          NaN
# totalImages                        NaN       NaN          NaN          NaN
# totalVideos                        NaN       NaN          NaN          NaN
# totalCredits                       NaN       1.0          NaN          NaN
# criticReviewsTotal                 NaN       NaN          NaN          NaN
# awardNominationsExcludeWins        NaN       NaN          NaN          NaN
# canHaveEpisodes                    NaN       NaN          NaN          NaN
# isRatable                          NaN       NaN          NaN          NaN
# isAdult                            NaN       NaN          NaN          NaN
# numRegions                         NaN      -1.0          NaN          NaN
# userReviewsTotal                   NaN       1.0          NaN          NaN
# ratingCount                        NaN       1.0          NaN          NaN
#
#                              totalCredits  criticReviewsTotal  \
# rating                                1.0                 NaN
# startYear                            -1.0                 NaN
# endYear                               NaN                 NaN
# runtimeMinutes                        NaN                 NaN
# awardWins                             NaN                 NaN
# numVotes                              1.0                 NaN
# totalImages                           NaN                 NaN
# totalVideos                           NaN                 NaN
# totalCredits                          1.0                 NaN
# criticReviewsTotal                    NaN                 NaN
# awardNominationsExcludeWins           NaN                 NaN
# canHaveEpisodes                       NaN                 NaN
# isRatable                             NaN                 NaN
# isAdult                               NaN                 NaN
# numRegions                           -1.0                 NaN
# userReviewsTotal                      1.0                 NaN
# ratingCount                           1.0                 NaN
#
#                              awardNominationsExcludeWins  canHaveEpisodes  \
# rating                                               NaN              NaN
# startYear                                            NaN              NaN
# endYear                                              NaN              NaN
# runtimeMinutes                                       NaN              NaN
# awardWins                                            NaN              NaN
# numVotes                                             NaN              NaN
# totalImages                                          NaN              NaN
# totalVideos                                          NaN              NaN
# totalCredits                                         NaN              NaN
# criticReviewsTotal                                   NaN              NaN
# awardNominationsExcludeWins                          NaN              NaN
# canHaveEpisodes                                      NaN              NaN
# isRatable                                            NaN              NaN
# isAdult                                              NaN              NaN
# numRegions                                           NaN              NaN
# userReviewsTotal                                     NaN              NaN
# ratingCount                                          NaN              NaN
#
#                              isRatable  isAdult  numRegions  userReviewsTotal  \
# rating                             NaN      NaN        -1.0               1.0
# startYear                          NaN      NaN         1.0              -1.0
# endYear                            NaN      NaN         NaN               NaN
# runtimeMinutes                     NaN      NaN         NaN               NaN
# awardWins                          NaN      NaN         NaN               NaN
# numVotes                           NaN      NaN        -1.0               1.0
# totalImages                        NaN      NaN         NaN               NaN
# totalVideos                        NaN      NaN         NaN               NaN
# totalCredits                       NaN      NaN        -1.0               1.0
# criticReviewsTotal                 NaN      NaN         NaN               NaN
# awardNominationsExcludeWins        NaN      NaN         NaN               NaN
# canHaveEpisodes                    NaN      NaN         NaN               NaN
# isRatable                          NaN      NaN         NaN               NaN
# isAdult                            NaN      NaN         NaN               NaN
# numRegions                         NaN      NaN         1.0              -1.0
# userReviewsTotal                   NaN      NaN        -1.0               1.0
# ratingCount                        NaN      NaN        -1.0               1.0
#
#                              ratingCount
# rating                               1.0
# startYear                           -1.0
# endYear                              NaN
# runtimeMinutes                       NaN
# awardWins                            NaN
# numVotes                             1.0
# totalImages                          NaN
# totalVideos                          NaN
# totalCredits                         1.0
# criticReviewsTotal                   NaN
# awardNominationsExcludeWins          NaN
# canHaveEpisodes                      NaN
# isRatable                            NaN
# isAdult                              NaN
# numRegions                          -1.0
# userReviewsTotal                     1.0
# ratingCount                          1.0
#
# Correlation matrix for title 'Animal Hospital':
#                              rating  startYear  endYear  runtimeMinutes  \
# rating                          1.0       -1.0      NaN            -1.0
# startYear                      -1.0        1.0      NaN             1.0
# endYear                         NaN        NaN      NaN             NaN
# runtimeMinutes                 -1.0        1.0      NaN             1.0
# awardWins                       NaN        NaN      NaN             NaN
# numVotes                        1.0       -1.0      NaN            -1.0
# totalImages                     1.0       -1.0      NaN            -1.0
# totalVideos                     NaN        NaN      NaN             NaN
# totalCredits                    1.0       -1.0      NaN            -1.0
# criticReviewsTotal              NaN        NaN      NaN             NaN
# awardNominationsExcludeWins     1.0       -1.0      NaN            -1.0
# canHaveEpisodes                 NaN        NaN      NaN             NaN
# isRatable                       NaN        NaN      NaN             NaN
# isAdult                         NaN        NaN      NaN             NaN
# numRegions                      1.0       -1.0      NaN            -1.0
# userReviewsTotal                NaN        NaN      NaN             NaN
# ratingCount                     1.0       -1.0      NaN            -1.0
#
#                              awardWins  numVotes  totalImages  totalVideos  \
# rating                             NaN       1.0          1.0          NaN
# startYear                          NaN      -1.0         -1.0          NaN
# endYear                            NaN       NaN          NaN          NaN
# runtimeMinutes                     NaN      -1.0         -1.0          NaN
# awardWins                          NaN       NaN          NaN          NaN
# numVotes                           NaN       1.0          1.0          NaN
# totalImages                        NaN       1.0          1.0          NaN
# totalVideos                        NaN       NaN          NaN          NaN
# totalCredits                       NaN       1.0          1.0          NaN
# criticReviewsTotal                 NaN       NaN          NaN          NaN
# awardNominationsExcludeWins        NaN       1.0          1.0          NaN
# canHaveEpisodes                    NaN       NaN          NaN          NaN
# ...
#
#                              ratingCount
# rating                               NaN
# startYear                            1.0
# endYear                              NaN
# runtimeMinutes                       NaN
# awardWins                            NaN
# numVotes                             1.0
# totalImages                          1.0
# totalVideos                          NaN
# totalCredits                        -1.0
# criticReviewsTotal                   NaN
# awardNominationsExcludeWins          NaN
# canHaveEpisodes                      NaN
# isRatable                            NaN
# isAdult                              NaN
# numRegions                           NaN
# userReviewsTotal                     NaN
# ratingCount                          1.0
#
# Correlation matrix for title 'Zero':
#                              rating  startYear  endYear  runtimeMinutes  \
# rating                          1.0        1.0      NaN             1.0
# startYear                       1.0        1.0      NaN             1.0
# endYear                         NaN        NaN      NaN             NaN
# runtimeMinutes                  1.0        1.0      NaN             1.0
# awardWins                       NaN        NaN      NaN             NaN
# numVotes                        1.0        1.0      NaN             1.0
# totalImages                    -1.0       -1.0      NaN            -1.0
# totalVideos                     NaN        NaN      NaN             NaN
# totalCredits                    1.0        1.0      NaN             1.0
# criticReviewsTotal              NaN        NaN      NaN             NaN
# awardNominationsExcludeWins    -1.0       -1.0      NaN            -1.0
# canHaveEpisodes                 NaN        NaN      NaN             NaN
# isRatable                       NaN        NaN      NaN             NaN
# isAdult                         NaN        NaN      NaN             NaN
# numRegions                      NaN        NaN      NaN             NaN
# userReviewsTotal                1.0        1.0      NaN             1.0
# ratingCount                     1.0        1.0      NaN             1.0
#
#                              awardWins  numVotes  totalImages  totalVideos  \
# rating                             NaN       1.0         -1.0          NaN
# startYear                          NaN       1.0         -1.0          NaN
# endYear                            NaN       NaN          NaN          NaN
# runtimeMinutes                     NaN       1.0         -1.0          NaN
# awardWins                          NaN       NaN          NaN          NaN
# numVotes                           NaN       1.0         -1.0          NaN
# totalImages                        NaN      -1.0          1.0          NaN
# totalVideos                        NaN       NaN          NaN          NaN
# totalCredits                       NaN       1.0         -1.0          NaN
# criticReviewsTotal                 NaN       NaN          NaN          NaN
# awardNominationsExcludeWins        NaN      -1.0          1.0          NaN
# canHaveEpisodes                    NaN       NaN          NaN          NaN
# isRatable                          NaN       NaN          NaN          NaN
# isAdult                            NaN       NaN          NaN          NaN
# numRegions                         NaN       NaN          NaN          NaN
# userReviewsTotal                   NaN       1.0         -1.0          NaN
# ratingCount                        NaN       1.0         -1.0          NaN
#
#                              totalCredits  criticReviewsTotal  \
# rating                                1.0                 NaN
# startYear                             1.0                 NaN
# endYear                               NaN                 NaN
# runtimeMinutes                        1.0                 NaN
# awardWins                             NaN                 NaN
# numVotes                              1.0                 NaN
# totalImages                          -1.0                 NaN
# totalVideos                           NaN                 NaN
# totalCredits                          1.0                 NaN
# criticReviewsTotal                    NaN                 NaN
# awardNominationsExcludeWins          -1.0                 NaN
# canHaveEpisodes                       NaN                 NaN
# isRatable                             NaN                 NaN
# isAdult                               NaN                 NaN
# numRegions                            NaN                 NaN
# userReviewsTotal                      1.0                 NaN
# ratingCount                           1.0                 NaN
#
#                              awardNominationsExcludeWins  canHaveEpisodes  \
# rating                                              -1.0              NaN
# startYear                                           -1.0              NaN
# endYear                                              NaN              NaN
# runtimeMinutes                                      -1.0              NaN
# awardWins                                            NaN              NaN
# numVotes                                            -1.0              NaN
# totalImages                                          1.0              NaN
# totalVideos                                          NaN              NaN
# totalCredits                                        -1.0              NaN
# criticReviewsTotal                                   NaN              NaN
# awardNominationsExcludeWins                          1.0              NaN
# canHaveEpisodes                                      NaN              NaN
# isRatable                                            NaN              NaN
# isAdult                                              NaN              NaN
# numRegions                                           NaN              NaN
# userReviewsTotal                                    -1.0              NaN
# ratingCount                                         -1.0              NaN
#
#                              isRatable  isAdult  numRegions  userReviewsTotal  \
# rating                             NaN      NaN         NaN               1.0
# startYear                          NaN      NaN         NaN               1.0
# endYear                            NaN      NaN         NaN               NaN
# runtimeMinutes                     NaN      NaN         NaN               1.0
# awardWins                          NaN      NaN         NaN               NaN
# numVotes                           NaN      NaN         NaN               1.0
# totalImages                        NaN      NaN         NaN              -1.0
# totalVideos                        NaN      NaN         NaN               NaN
# totalCredits                       NaN      NaN         NaN               1.0
# criticReviewsTotal                 NaN      NaN         NaN               NaN
# awardNominationsExcludeWins        NaN      NaN         NaN              -1.0
# canHaveEpisodes                    NaN      NaN         NaN               NaN
# isRatable                          NaN      NaN         NaN               NaN
# isAdult                            NaN      NaN         NaN               NaN
# numRegions                         NaN      NaN         NaN               NaN
# userReviewsTotal                   NaN      NaN         NaN               1.0
# ratingCount                        NaN      NaN         NaN               1.0
#
#                              ratingCount
# rating                               1.0
# startYear                            1.0
# endYear                              NaN
# runtimeMinutes                       1.0
# awardWins                            NaN
# numVotes                             1.0
# totalImages                         -1.0
# totalVideos                          NaN
# totalCredits                         1.0
# criticReviewsTotal                   NaN
# awardNominationsExcludeWins         -1.0
# canHaveEpisodes                      NaN
# isRatable                            NaN
# isAdult                              NaN
# numRegions                           NaN
# userReviewsTotal                     1.0
# ratingCount                          1.0
#
# Correlation matrix for title 'Épisode 1':
#                              rating  startYear  endYear  runtimeMinutes  \
# rating                          1.0       -1.0      NaN             1.0
# startYear                      -1.0        1.0      NaN            -1.0
# endYear                         NaN        NaN      NaN             NaN
# runtimeMinutes                  1.0       -1.0      NaN             1.0
# awardWins                       NaN        NaN      NaN             NaN
# numVotes                        NaN        NaN      NaN             NaN
# totalImages                    -1.0        1.0      NaN            -1.0
# totalVideos                     NaN        NaN      NaN             NaN
# totalCredits                   -1.0        1.0      NaN            -1.0
# criticReviewsTotal              NaN        NaN      NaN             NaN
# awardNominationsExcludeWins     NaN        NaN      NaN             NaN
# canHaveEpisodes                 NaN        NaN      NaN             NaN
# isRatable                       NaN        NaN      NaN             NaN
# isAdult                         NaN        NaN      NaN             NaN
# numRegions                      NaN        NaN      NaN             NaN
# userReviewsTotal                NaN        NaN      NaN             NaN
# ratingCount                     NaN        NaN      NaN             NaN
#
#                              awardWins  numVotes  totalImages  totalVideos  \
# rating                             NaN       NaN         -1.0          NaN
# startYear                          NaN       NaN          1.0          NaN
# endYear                            NaN       NaN          NaN          NaN
# runtimeMinutes                     NaN       NaN         -1.0          NaN
# awardWins                          NaN       NaN          NaN          NaN
# numVotes                           NaN       NaN          NaN          NaN
# totalImages                        NaN       NaN          1.0          NaN
# totalVideos                        NaN       NaN          NaN          NaN
# totalCredits                       NaN       NaN          1.0          NaN
# criticReviewsTotal                 NaN       NaN          NaN          NaN
# awardNominationsExcludeWins        NaN       NaN          NaN          NaN
# canHaveEpisodes                    NaN       NaN          NaN          NaN
# isRatable                          NaN       NaN          NaN          NaN
# isAdult                            NaN       NaN          NaN          NaN
# numRegions                         NaN       NaN          NaN          NaN
# userReviewsTotal                   NaN       NaN          NaN          NaN
# ratingCount                        NaN       NaN          NaN          NaN
#
#                              totalCredits  criticReviewsTotal  \
# rating                               -1.0                 NaN
# startYear                             1.0                 NaN
# endYear                               NaN                 NaN
# runtimeMinutes                       -1.0                 NaN
# awardWins                             NaN                 NaN
# numVotes                              NaN                 NaN
# totalImages                           1.0                 NaN
# totalVideos                           NaN                 NaN
# totalCredits                          1.0                 NaN
# criticReviewsTotal                    NaN                 NaN
# awardNominationsExcludeWins           NaN                 NaN
# canHaveEpisodes                       NaN                 NaN
# isRatable                             NaN                 NaN
# isAdult                               NaN                 NaN
# numRegions                            NaN                 NaN
# userReviewsTotal                      NaN                 NaN
# ratingCount                           NaN                 NaN
#
#                              awardNominationsExcludeWins  canHaveEpisodes  \
# rating                                               NaN              NaN
# startYear                                            NaN              NaN
# endYear                                              NaN              NaN
# runtimeMinutes                                       NaN              NaN
# awardWins                                            NaN              NaN
# numVotes                                             NaN              NaN
# totalImages                                          NaN              NaN
# totalVideos                                          NaN              NaN
# totalCredits                                         NaN              NaN
# criticReviewsTotal                                   NaN              NaN
# awardNominationsExcludeWins                          NaN              NaN
# canHaveEpisodes                                      NaN              NaN
# isRatable                                            NaN              NaN
# isAdult                                              NaN              NaN
# numRegions                                           NaN              NaN
# userReviewsTotal                                     NaN              NaN
# ratingCount                                          NaN              NaN
#
#                              isRatable  isAdult  numRegions  userReviewsTotal  \
# rating                             NaN      NaN         NaN               NaN
# startYear                          NaN      NaN         NaN               NaN
# endYear                            NaN      NaN         NaN               NaN
# runtimeMinutes                     NaN      NaN         NaN               NaN
# awardWins                          NaN      NaN         NaN               NaN
# numVotes                           NaN      NaN         NaN               NaN
# totalImages                        NaN      NaN         NaN               NaN
# totalVideos                        NaN      NaN         NaN               NaN
# totalCredits                       NaN      NaN         NaN               NaN
# criticReviewsTotal                 NaN      NaN         NaN               NaN
# awardNominationsExcludeWins        NaN      NaN         NaN               NaN
# canHaveEpisodes                    NaN      NaN         NaN               NaN
# isRatable                          NaN      NaN         NaN               NaN
# isAdult                            NaN      NaN         NaN               NaN
# numRegions                         NaN      NaN         NaN               NaN
# userReviewsTotal                   NaN      NaN         NaN               NaN
# ratingCount                        NaN      NaN         NaN               NaN
#
#                              ratingCount
# rating                               NaN
# startYear                            NaN
# endYear                              NaN
# runtimeMinutes                       NaN
# awardWins                            NaN
# numVotes                             NaN
# totalImages                          NaN
# totalVideos                          NaN
# totalCredits                         NaN
# criticReviewsTotal                   NaN
# awardNominationsExcludeWins          NaN
# canHaveEpisodes                      NaN
# isRatable                            NaN
# isAdult                              NaN
# numRegions                           NaN
# userReviewsTotal                     NaN
# ratingCount                          NaN

# %%
# Check presence of NaNs
nan_percentage = df.isna().mean() * 100
nan_percentage
# Out:
# originalTitle                   0.000000
# rating                          0.000000
# startYear                       0.000000
# endYear                        95.045950
# runtimeMinutes                 29.529548
# awardWins                      15.933297
# numVotes                        0.000000
# totalImages                     0.000000
# totalVideos                     0.000000
# totalCredits                    0.000000
# criticReviewsTotal              0.000000
# titleType                       0.000000
# awardNominationsExcludeWins     0.000000
# canHaveEpisodes                 0.000000
# isRatable                       0.000000
# isAdult                         0.000000
# numRegions                      0.000000
# userReviewsTotal                0.000000
# ratingCount                     0.000000
# countryOfOrigin                 0.000000
# genre1                          2.324874
# genre2                         38.494310
# genre3                         68.918508
# dtype: float64

# %%
# Group by 'titleType' and compute the mean of 'runtimeMinutes' for each group
mean_runtime = df.groupby('titleType')['runtimeMinutes'].transform('mean')

# Fill NaN values in 'runtimeMinutes' with the mean of the respective 'titleType'
df['runtimeMinutes'] = df['runtimeMinutes'].fillna(mean_runtime).astype(int)
df
# Out:
#                                  originalTitle  rating  startYear  endYear  \
# 0      Neogenic Nightmare Chapter 3: Hydro-Man       8       1995      NaN
# 1                                      Looping       6       1982      NaN
# 2                               Idealnaya para       6       1992      NaN
# 3                  MasterChef Celebrity México       6       2021      NaN
# 4                                  Seutateueob       8       2020   2020.0
# ...                                        ...     ...        ...      ...
# 16426                                 Caprices       6       1942      NaN
# 16427                                Haar Jeet       5       1990      NaN
# 16428                              Kotigobba 3       6       2021      NaN
# 16429                       Ator l'invincibile       4       1982      NaN
# 16430                        Anniversary Night      10       2022      NaN
#
#        runtimeMinutes  awardWins  numVotes  totalImages  totalVideos  \
# 0                  40        0.0       779            1            0
# 1                  28        0.0        11            1            0
# 2                  92        0.0        38            1            0
# 3                  53        0.0        15           22            0
# 4                  80        1.0     15718          347            2
# ...               ...        ...       ...          ...          ...
# 16426              92        0.0        73            4            0
# 16427              92        0.0        15            2            0
# 16428             140        0.0      2560           39            3
# 16429              92        0.0      3011           52            1
# 16430              13        0.0         9            7            0
#
#        totalCredits  ...  canHaveEpisodes isRatable  isAdult  numRegions  \
# 0                21  ...            False      True    False           1
# 1                 1  ...            False      True    False           1
# 2                24  ...            False      True    False           1
# 3                56  ...             True      True    False           1
# 4                47  ...             True      True    False          32
# ...             ...  ...              ...       ...      ...         ...
# 16426            45  ...            False      True    False          14
# 16427            22  ...            False      True    False           1
# 16428           129  ...            False      True    False           5
# 16429            53  ...            False      True    False          26
# 16430            19  ...            False      True    False           1
#
#        userReviewsTotal  ratingCount  countryOfOrigin      genre1     genre2  \
# 0                     0          781           ['US']      Action  Adventure
# 1                     0           11          ['XWG']      Action       None
# 2                     1           38           ['RU']      Comedy       None
# 3                     0           15           ['MX']  Reality-Tv       None
# 4                   452        15746           ['KR']      Comedy      Drama
# ...                 ...          ...              ...         ...        ...
# 16426                 4           73           ['FR']      Comedy       None
# 16427                 1           15           ['IN']      Action      Drama
# 16428                49         2560           ['IN']      Action      Drama
# 16429                58         3012           ['IT']      Action  Adventure
# 16430                 0            9           ['IN']       Drama      Short
#
#           genre3
# 0      Animation
# 1           None
# 2           None
# 3           None
# 4        Romance
# ...          ...
# 16426       None
# 16427   Thriller
# 16428    Romance
# 16429    Fantasy
# 16430       None
#
# [16431 rows x 23 columns]

# %%
### Compute correlation.
corr = df.corr(method='pearson', numeric_only=True)
# Show correlations higher than 0.7.
filt_corr = corr[(corr > 0.7) & (corr < 1)]
result = filt_corr.stack().reset_index()
result.columns = ['rowIndex', 'columnIndex', 'correlation']
result = result[result['rowIndex'] < result['columnIndex']]
print(result)
del corr
del filt_corr
del result
# Out:
#       rowIndex       columnIndex  correlation
# 1      endYear         startYear     0.951679
# 2     numVotes  userReviewsTotal     0.752175
# 3     numVotes       ratingCount     1.000000
# 7  ratingCount  userReviewsTotal     0.752223

# %%
### Remove correlated cells numVotes and ratingCount. New column totVotes as the mean.
df['totVotes'] = df[['numVotes', 'ratingCount']].mean(axis=1).astype(int)
df.drop('ratingCount', axis=1, inplace=True)
df.drop('numVotes', axis=1, inplace=True)
df.head()
# Out:
#                              originalTitle  rating  startYear  endYear  \
# 0  Neogenic Nightmare Chapter 3: Hydro-Man       8       1995      NaN
# 1                                  Looping       6       1982      NaN
# 2                           Idealnaya para       6       1992      NaN
# 3              MasterChef Celebrity México       6       2021      NaN
# 4                              Seutateueob       8       2020   2020.0
#
#    runtimeMinutes  awardWins  totalImages  totalVideos  totalCredits  \
# 0              40        0.0            1            0            21
# 1              28        0.0            1            0             1
# 2              92        0.0            1            0            24
# 3              53        0.0           22            0            56
# 4              80        1.0          347            2            47
#
#    criticReviewsTotal  ... canHaveEpisodes  isRatable  isAdult  numRegions  \
# 0                   1  ...           False       True    False           1
# 1                   0  ...           False       True    False           1
# 2                   0  ...           False       True    False           1
# 3                   0  ...            True       True    False           1
# 4                   4  ...            True       True    False          32
#
#    userReviewsTotal  countryOfOrigin      genre1     genre2     genre3  \
# 0                 0           ['US']      Action  Adventure  Animation
# 1                 0          ['XWG']      Action       None       None
# 2                 1           ['RU']      Comedy       None       None
# 3                 0           ['MX']  Reality-Tv       None       None
# 4               452           ['KR']      Comedy      Drama    Romance
#
#   totVotes
# 0      780
# 1       11
# 2       38
# 3       15
# 4    15732
#
# [5 rows x 22 columns]

# %% [markdown]
# # Clustering

# %%
# There are lots of NaN values in the endYear and awardWins columns.
# For EndYear is better to drop the column (for semantics).
# For awardWins could all NaNs be converted to 0?
# Also, canHaveEpisodes could be relevant for the analysis, so it is converted to number.
num_df = df.drop('endYear', axis=1)
#num_df['canHaveEpisodes'] = df['canHaveEpisodes'].astype('int')
num_df = num_df.select_dtypes(include=['number'])
num_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16431 entries, 0 to 16430
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   rating                       16431 non-null  int64
#  1   startYear                    16431 non-null  int64
#  2   runtimeMinutes               16431 non-null  int64
#  3   awardWins                    13813 non-null  float64
#  4   totalImages                  16431 non-null  int64
#  5   totalVideos                  16431 non-null  int64
#  6   totalCredits                 16431 non-null  int64
#  7   criticReviewsTotal           16431 non-null  int64
#  8   awardNominationsExcludeWins  16431 non-null  int64
#  9   numRegions                   16431 non-null  int64
#  10  userReviewsTotal             16431 non-null  int64
#  11  totVotes                     16431 non-null  int64
# dtypes: float64(1), int64(11)
# memory usage: 1.5 MB

# %%
# For awardWins could all NaNs be converted to 0?
# It doesn't have a strong correlation with any other numerical values.
# The column is kept with awardWins as 0
# Correlation between awardWins and everything else.
print(num_df.corr()['awardWins'])
# Mean values on awardNominationsExcludeWins having awardWins as NaN.
num_df[num_df['awardWins'].isna()][['awardWins', 'awardNominationsExcludeWins']]['awardNominationsExcludeWins'].describe()
# It seems like if awardWins is NaN, then, awardNominationsExcludeWins is in general very close to zero.
# Out:
# rating                         0.055754
# startYear                      0.076407
# runtimeMinutes                 0.068093
# awardWins                      1.000000
# totalImages                    0.208862
# totalVideos                    0.178123
# totalCredits                   0.191245
# criticReviewsTotal             0.361878
# awardNominationsExcludeWins    0.693788
# numRegions                     0.281677
# userReviewsTotal               0.281566
# totVotes                       0.351500
# Name: awardWins, dtype: float64
# count    2618.000000
# mean        0.133308
# std         0.726820
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        12.000000
# Name: awardNominationsExcludeWins, dtype: float64

# %%
# Put Zero where "awardWins" is NaN.
num_df['awardWins'].fillna(0, inplace=True)
# Out:
# C:\Users\curia\AppData\Local\Temp\ipykernel_21032\1889949969.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   num_df['awardWins'].fillna(0, inplace=True)

# %%
# Let's see how clustering can guess the "titleType".
df['titleType'].unique()
# Out:
# array(['tvEpisode', 'videoGame', 'movie', 'tvSeries', 'video',
#        'tvMiniSeries', 'short', 'tvMovie', 'tvSpecial', 'tvShort'],
#       dtype=object)

# %%
# Prepare for K-Means.
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import silhouette_score

num_df_copy = num_df.copy(True)

# Normalize numeric dataframe.
scaler = MinMaxScaler()
num_df = scaler.fit_transform(num_df)

# Encode "tytleType".
label_encoder = LabelEncoder()
df['titleTypeNumeric'] = label_encoder.fit_transform(df['titleType'])
df['titleTypeNumeric'].describe()
df.to_csv('cluster_test.csv', index=False)

# %%
inertias = []
silhouette = []

for i in range(2,11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(num_df)
    inertias.append(kmeans.inertia_)
    silhouette.append(silhouette_score(num_df, kmeans.labels_))

plt.plot(range(2,11), inertias, marker='o')
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show() 

plt.figure(figsize=(8, 5))
plt.plot(range(2,11), silhouette, marker='o')
plt.title('Silhouette Scores for Different k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.grid(True)
plt.show()

# %%
# Analyzing all numeric columns together doesn't give any meaningfull clustering on titleType. 
kmeans = KMeans(n_clusters=8)
kmeans.fit(num_df)
df['clustering'] = kmeans.labels_
df[['clustering', 'titleTypeNumeric']].corr()
result = df.groupby('titleType')['clustering'].unique().reset_index()
result
# Out:
#       titleType                clustering
# 0         movie  [1, 2, 4, 7, 6, 0, 3, 5]
# 1         short        [0, 4, 6, 1, 2, 3]
# 2     tvEpisode        [3, 0, 1, 4, 2, 6]
# 3  tvMiniSeries        [0, 4, 3, 1, 7, 2]
# 4       tvMovie     [0, 3, 1, 4, 2, 7, 6]
# 5      tvSeries  [4, 7, 2, 0, 3, 1, 6, 5]
# 6       tvShort           [0, 1, 3, 4, 2]
# 7     tvSpecial        [3, 0, 4, 2, 1, 7]
# 8         video        [0, 3, 4, 2, 1, 7]
# 9     videoGame           [1, 0, 4, 3, 2]

# %%
cluster_counts = pd.crosstab(df['clustering'], df['titleType'])

# Convert counts to percentages
cluster_percentages = cluster_counts.div(cluster_counts.sum(axis=1), axis=0) * 100

# Plot the stacked bar chart
plt.figure(figsize=(10, 6))
bottom = None  # Initial value for stacking

# Loop through each column (titleType) to stack bars
for title_type in cluster_percentages.columns:
    if bottom is None:
        bottom = cluster_percentages[title_type]
        plt.bar(cluster_percentages.index, cluster_percentages[title_type], label=title_type)
    else:
        plt.bar(cluster_percentages.index, cluster_percentages[title_type], bottom=bottom, label=title_type)
        bottom += cluster_percentages[title_type]

# Add labels and legend
plt.title('Percentage of Title Types in Each Cluster', fontsize=16)
plt.xlabel('Cluster', fontsize=14)
plt.ylabel('Percentage (%)', fontsize=14)
plt.legend(title='Title Type', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()

# %%
num_df_copy.head()
two_df = num_df_copy[['runtimeMinutes', 'totalCredits']]
two_df.head()

# Normalize numeric dataframe.
two_df = scaler.fit_transform(two_df)
inertias = []
silhouette = []

for i in range(2,11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(two_df)
    inertias.append(kmeans.inertia_)
    silhouette.append(silhouette_score(two_df, kmeans.labels_))

plt.plot(range(2,11), inertias, marker='o')
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show() 

plt.figure(figsize=(8, 5))
plt.plot(range(2,11), silhouette, marker='o')
plt.title('Silhouette Scores for Different k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.grid(True)
plt.show()

# %%
# Analyzing all numeric columns together doesn't give any meaningfull clustering on titleType. 
kmeans = KMeans(n_clusters=8)
kmeans.fit(num_df)
df['clustering'] = kmeans.labels_
df[['clustering', 'titleTypeNumeric']].corr()
result = df.groupby('titleType')['clustering'].unique().reset_index()
result
# Out:
#       titleType                clustering
# 0         movie  [4, 1, 0, 6, 5, 2, 3, 7]
# 1         short     [7, 6, 2, 4, 3, 0, 1]
# 2     tvEpisode     [7, 3, 1, 4, 0, 6, 2]
# 3  tvMiniSeries     [7, 3, 6, 1, 4, 5, 0]
# 4       tvMovie  [3, 7, 4, 6, 1, 0, 5, 2]
# 5      tvSeries  [0, 5, 6, 3, 7, 1, 2, 4]
# 6       tvShort        [7, 1, 0, 4, 3, 6]
# 7     tvSpecial     [1, 3, 7, 6, 0, 4, 5]
# 8         video     [3, 1, 4, 0, 6, 7, 5]
# 9     videoGame        [4, 7, 3, 1, 6, 0]

# %%
# Scatterplot of the clusters
plt.figure(figsize=(8, 6))
for cluster_id in df['clustering'].unique():
    cluster_data = df[df['clustering'] == cluster_id]
    plt.scatter(cluster_data['runtimeMinutes'], cluster_data['totalCredits'], label=f'Cluster {cluster_id}')

# Plot centroids
centroids = kmeans.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X', s=200, label='Centroids')

plt.xlabel('x')
plt.ylabel('y')
plt.title('K-Means Clustering')
plt.legend()
plt.show()

# %%
data = pd.read_csv("data/train.csv")  # Cambia il nome con il file corretto

# 1. Distribuzione dei generi
plt.figure(figsize=(10, 6))
data['genres'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribuzione dei Generi')
plt.xlabel('Genere')
plt.ylabel('Conteggio')
plt.xticks(rotation=45)
plt.show()
